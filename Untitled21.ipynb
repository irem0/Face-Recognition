# %%
# !pip install tensorflow scikit-learn numpy opencv-python mtcnn matplotlib

# %%
pip uninstall tensorflow -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping tensorflow as it is not installed.

# %%
pip install tensorflow-cpu
# Out:
# ...
#   Using cached tensorflow_intel-2.18.0-cp310-cp310-win_amd64.whl (390.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\BurNet\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\tensorflow\\include\\external\\com_github_grpc_grpc\\src\\core\\ext\\filters\\client_channel\\lb_policy\\grpclb\\client_load_reporting_filter.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 23.0 -> 24.3.1
# [notice] To update, run: C:\Users\BurNet\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !where python
# Out:
# c:\Users\BurNet\AppData\Local\Microsoft\WindowsApps\python.exe
# C:\Python312\python.exe
# C:\msys64\ucrt64\bin\python.exe

# %%
import tensorflow as tf
import cv2
import numpy as np
from mtcnn import MTCNN
from keras_facenet import FaceNet
from sklearn.svm import SVC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import tensorflow as tf
#       2 import cv2
#       3 import numpy as np
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import cv2
from mtcnn.mtcnn import MTCNN
from keras_facenet import FaceNet
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.svm import SVC
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.models import load_model
import numpy as np
import pickle

# Fine-tuned model
fine_tuned_model = load_model('fine_tuned_model.h5')

# Embedding verileri
embedded_train = np.load('embedded_train.npy')
embedded_test = np.load('embedded_test.npy')

# SVM model
with open('svm_model.pkl', 'rb') as file:
    svm_model = pickle.load(file)
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class FACELOADING:
    def __init__(self, directory):
        self.directory = directory
        self.target_size = (160, 160)
        self.X = []
        self.Y = []
        self.detector = MTCNN()

    def extract_face(self, filename):
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = self.detector.detect_faces(img)
        if len(results) == 0:
            return None
        x, y, w, h = results[0]['box']
        x, y = abs(x), abs(y)
        face = img[y:y+h, x:x+w]
        face_arr = cv2.resize(face, self.target_size)
        return face_arr

    def load_faces_in_dir(self, dir_path):
        faces_list = []
        for im_name in os.listdir(dir_path):
            path = os.path.join(dir_path, im_name)
            if not os.path.isfile(path):
                continue
            try:
                face_arr = self.extract_face(path)
                if face_arr is not None:
                    faces_list.append(face_arr)
            except:
                pass
        return faces_list

    def load_classes(self):
        for sub_dir in os.listdir(self.directory):
            class_path = os.path.join(self.directory, sub_dir)
            if not os.path.isdir(class_path):
                continue
            FACES = self.load_faces_in_dir(class_path)
            labels = [sub_dir for _ in range(len(FACES))]
            print(f"Person: {sub_dir}, loaded faces: {len(labels)}")
            self.X.extend(FACES)
            self.Y.extend(labels)
        return np.asarray(self.X), np.asarray(self.Y)

# %%
# Veri Yükleme
base_dir = "/content/drive/MyDrive/dataset"  # Dataset yolunuzu ayarlayın
faceload = FACELOADING(base_dir)
X, Y = faceload.load_classes()

# Veriyi Train-Test Çevirme
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)
# Out:
# Person: Özge Sersan, loaded faces: 15
# Person: Aleyna Göktaş, loaded faces: 30
# Person: Gül Şifa, loaded faces: 21
# Person: İrem İçöz, loaded faces: 24
# Person: Büşra Polatoğlu, loaded faces: 24
# Person: Melike Şahin, loaded faces: 19
# Person: Damla Soydan, loaded faces: 29
# Person: Bengüsu Akdoğan, loaded faces: 30
# Person: Zeynep Kılınçer, loaded faces: 16
# Person: Şeyma Çelebi, loaded faces: 22
# Person: Şeyma İlgün, loaded faces: 15

# %%
# Label Encoding
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train)
y_test_encoded = encoder.transform(y_test)

# 2. Augmentation ve Normalizasyon
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalizasyon
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)
val_datagen = ImageDataGenerator(rescale=1.0/255)

train_gen = train_datagen.flow(np.array(X_train), y_train_encoded, batch_size=32)
val_gen = val_datagen.flow(np.array(X_test), y_test_encoded, batch_size=32)

# %%
# FaceNet Modeli ve Fine-Tuning
embedder = FaceNet()
facenet_model = embedder.model

x = facenet_model.layers[-2].output  # Son embedding çıkışı
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(len(np.unique(Y)), activation='softmax')(x)

fine_tuned_model = Model(inputs=facenet_model.input, outputs=output)

for layer in facenet_model.layers[:-10]:
    layer.trainable = False

fine_tuned_model.compile(optimizer=Adam(learning_rate=1e-5),
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])

# %%
# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Model Eğitimi
history = fine_tuned_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=70,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.1432 - loss: 2.8920 - val_accuracy: 0.2041 - val_loss: 2.6230
# Epoch 2/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.0932 - loss: 3.0858 - val_accuracy: 0.2449 - val_loss: 2.4793
# Epoch 3/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.0881 - loss: 2.7893 - val_accuracy: 0.3061 - val_loss: 2.3331
# Epoch 4/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.1370 - loss: 2.7873 - val_accuracy: 0.3061 - val_loss: 2.2019
# Epoch 5/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.1678 - loss: 2.5412 - val_accuracy: 0.3265 - val_loss: 2.0751
# Epoch 6/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.1791 - loss: 2.3868 - val_accuracy: 0.3265 - val_loss: 1.9524
# Epoch 7/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.2664 - loss: 2.1898 - val_accuracy: 0.3469 - val_loss: 1.8322
# Epoch 8/70
# ...

# %%
# Embedding Modeli Oluşturma
embedding_layer = Model(inputs=fine_tuned_model.input, outputs=fine_tuned_model.layers[-2].output)

# Embedding Çıkışları
embedded_train = np.array([embedding_layer.predict(np.expand_dims(face/255.0, axis=0))[0] for face in X_train])
embedded_test = np.array([embedding_layer.predict(np.expand_dims(face/255.0, axis=0))[0] for face in X_test])

# Normalizasyon
norm = Normalizer(norm='l2')
embedded_train = norm.fit_transform(embedded_train)
embedded_test = norm.transform(embedded_test)

# SVM Modeli
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(embedded_train, y_train_encoded)

# Test Performansı
y_pred_svm = svm_model.predict(embedded_test)
print(classification_report(y_test_encoded, y_pred_svm, target_names=encoder.classes_))

# Confusion Matrix
cm = confusion_matrix(y_test_encoded, y_pred_svm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation='vertical')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ...

# %%
# Eğitim ve Doğrulama Metrikleri Görselleştirme
plt.figure(figsize=(14, 6))

# Accuracy Grafiği
plt.subplot(1, 2, 1)
plt.plot(history.history.get('accuracy', []), label='Train Accuracy', marker='o')
plt.plot(history.history.get('val_accuracy', []), label='Validation Accuracy', marker='o')
plt.title('Accuracy Over Epochs', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid()

# Loss Grafiği
plt.subplot(1, 2, 2)
plt.plot(history.history.get('loss', []), label='Train Loss', marker='o')
plt.plot(history.history.get('val_loss', []), label='Validation Loss', marker='o')
plt.title('Loss Over Epochs', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Confusion Matrix oluşturma
cm = confusion_matrix(y_test_encoded, y_pred_svm)

# Confusion Matrix görselleştirme
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
disp.plot(cmap='Blues', xticks_rotation=90)  # İsimleri dik döndürmek için xticks_rotation=90
plt.title("Confusion Matrix")
plt.show()

# Accuracy Karşılaştırması
accuracy_data = {
    'Method': ['Fine-Tune Only', 'Fine-Tune + SVM'],
    'Accuracy': [val_acc, accuracy_svm]
}
plt.figure(figsize=(8, 6))
sns.barplot(x='Method', y='Accuracy', data=pd.DataFrame(accuracy_data), palette='Blues')
plt.title("Accuracy Comparison")
plt.ylabel("Accuracy")
plt.ylim(0, 1)  # Y-axis'i 0-1 arasında ayarla
plt.show()
from sklearn.metrics import classification_report
import pandas as pd

report = classification_report(y_test_encoded, y_pred_svm, target_names=encoder.classes_, output_dict=True)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(10, 6))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Classification Report Heatmap", fontsize=16)
plt.xlabel("Metrics", fontsize=14)
plt.ylabel("Classes", fontsize=14)
plt.show()
# Out:
# <ipython-input-79-090418ae17ae>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Method', y='Accuracy', data=pd.DataFrame(accuracy_data), palette='Blues')

# %%
import cv2 as cv
import matplotlib.pyplot as plt
from mtcnn import MTCNN
import numpy as np

def turkish_to_ascii(text):
    """
    Türkçe karakterleri ASCII karakterlerine çevirir.
    """
    replacements = {
        'Ç': 'C', 'ç': 'c',
        'Ğ': 'G', 'ğ': 'g',
        'İ': 'I', 'ı': 'i',
        'Ö': 'O', 'ö': 'o',
        'Ş': 'S', 'ş': 's',
        'Ü': 'U', 'ü': 'u'
    }
    for turkish_char, ascii_char in replacements.items():
        text = text.replace(turkish_char, ascii_char)
    return text

def recognize_faces_in_image(image_path, model, embedding_layer, label_encoder, normalizer, threshold=0.5):
    """
    Test görüntüsünde yüz tanıma ve sınıflandırma işlemi yapar.
    """
    detector = MTCNN()
    img_bgr = cv.imread(image_path)
    if img_bgr is None:
        print("Cannot read image:", image_path)
        return
    img_rgb = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)

    results = detector.detect_faces(img_rgb)

    for r in results:
        x, y, w, h = r['box']
        x2, y2 = x + w, y + h

        # Yüzü kırp ve normalize et
        face = img_rgb[y:y2, x:x2]
        face = cv.resize(face, (160, 160))
        face = np.expand_dims(face / 255.0, axis=0)

        # Embedding çıkarım
        face_emb = embedding_layer.predict(face)[0]  # (512,)
        face_emb = normalizer.transform([face_emb])  # Normalizasyon

        # Sınıf tahmini yap
        yhat_class = model.predict(face_emb)[0]
        yhat_prob = model.predict_proba(face_emb)[0][yhat_class]

        if yhat_prob < threshold:
            text = "Unknown"
        else:
            class_name = label_encoder.inverse_transform([yhat_class])[0]
            class_name = turkish_to_ascii(class_name)  # Türkçe karakterleri ASCII'ye çevir
            text = f"{class_name} ({yhat_prob*100:.1f}%)"

        # Metinleri ASCII formatına çevir
        text = text.encode('ascii', 'ignore').decode('ascii')

        # Bounding box ve metin ekle
        cv.rectangle(img_bgr, (x, y), (x2, y2), (0, 0, 255), 2)
        cv.putText(img_bgr, text, (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Sonucu görselleştir
    plt.figure(figsize=(10, 8))
    plt.imshow(cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title("Face Recognition Results", fontsize=16)
    plt.show()

# %%
# Örnek kullanım:
test_img_path = "/content/drive/MyDrive/TEST/WhatsApp Image 2024-12-30 at 17.39.07.jpeg"
recognize_faces_in_image(
    image_path=test_img_path,
    model=svm_model,          # Eğitilmiş SVM modeli
    embedding_layer=embedding_layer,  # Fine-tuned FaceNet embedding layer
    label_encoder=encoder,    # Sınıf isimlerini içeren etiket dönüştürücü
    normalizer=norm,          # Embedding için normalizasyon
    threshold=0.5             # Tanımama sınırı (50%)
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
